# %% [markdown]
# 1. Read FairDealCustomerData.csv
# 2. Name field contains full name – use a regular expression to separate title, first
# name, last name
# 3. Store the data in Customer Class
# 4. Create Custom Exception – CustomerNotAllowedException
# 5. Pass a customer to function "createOrder" and throw
# CustomerNotAllowedException in case of blacklisted value is 1

# %%
import pandas as pd
data = pd.read_csv('FairDealCustomerData.csv', header=None, names=['Name', 'FullName', 'BlackListed'])
data.head()
# Out:
#          Name             FullName  BlackListed
# 0      Braund     Mr. Owen Harris             1
# 1   Heikkinen         Miss. Laina             0
# 2       Allen   Mr. William Henry             0
# 3       Moran           Mr. James             0
# 4    McCarthy       Mr. Timothy J             0

# %%
import re

def split_name(name, prop):
    regex = r'^(?P<title>\S+).\s{1}(?P<fname>\S+)(?:\s{1})?(?P<lname>\S+)?$'

    result = re.match(regex, name.strip())

    if result == None:
        return;

    if prop == 'title':
        return result.group('title')
    elif prop == 'first_name':
        return result.group('fname')
    elif prop == 'last_name':
        return result.group('lname')

# %%
class Customer:
    def __init__(self, lastName, firstName, title, blackListed):
        self.lastName = lastName
        self.firstName = firstName
        self.title = title
        self.blackListed = blackListed

# %%
data['title'] =  data['FullName'].apply(split_name, prop = 'title')
data['first_name'] =  data['FullName'].apply(split_name, prop = 'first_name')
data['last_name'] =  data['FullName'].apply(split_name, prop = 'last_name')

# %%
data.head()
# Out:
#          Name             FullName  BlackListed title first_name last_name
# 0      Braund     Mr. Owen Harris             1    Mr       Owen    Harris
# 1   Heikkinen         Miss. Laina             0  Miss      Laina      None
# 2       Allen   Mr. William Henry             0    Mr    William     Henry
# 3       Moran           Mr. James             0    Mr      James      None
# 4    McCarthy       Mr. Timothy J             0    Mr    Timothy         J

# %%
class CustomerNotAllowedException(Exception):
    def __init__(self,msg):
        self.msg=msg
        print( 'Customer Not Allowed.')

# %%
def createOrder(customer_data):
    if customer_data.blackListed == 1:
        print("-----")
        raise CustomerNotAllowedException(f"Customer {customer_data.title} {customer_data.firstName} {customer_data.lastName} is black-listed.")
    print(customer_data.firstName, customer_data.lastName, customer_data.title)

def process(customer):
    customer_data = Customer(customer['last_name'], customer['first_name'], customer['title'], customer['BlackListed'])
    try:
        createOrder(customer_data)
    except CustomerNotAllowedException as e:
        print(e.msg)
        print("-----")

# %%
data.apply(process, axis=1)
# Out:
# -----
# Customer Not Allowed.
# Customer Mr Owen Harris is black-listed.
# -----
# Laina None Miss
# William Henry Mr
# James None Mr
# Timothy J Mr
# Elizabeth None Miss
# Anders Johan Mr
# -----
# Customer Not Allowed.
# Customer Mr Charles Eugene is black-listed.
# -----
# Fatima None Mrs
# Joseph J Mr
# Lawrence None Mr
# William Thompson Mr
# Farred Chehab Mr
# Lalio None Mr
# -----
# Customer Not Allowed.
# Customer Don Manuel E is black-listed.
# -----
# Mary Agatha Miss
# Edward H Mr
# Edgar Joseph Mr
# Alexander Oskar Mr
# Hanna None Mr
# Theodor None Mr
# -----
# Customer Not Allowed.
# Customer Mr William John is black-listed.
# Customer Not Allowed.
# Customer None None None is black-listed.
# -----
# Pieta Sofia Miss
# Elisabeth Walton Miss
# Robert J Mr
# William John Mr
# Moses Aaron Mr
# Leslie None Mr
# -----
# Customer Not Allowed.
# Customer Mr Gustave J is black-listed.
# -----
# Kanio None Mr
# Minko None Mr
# Walter James Mr
# Tyrell William Mr
# Neal None Mr
# Juho None Mr
# -----
# Customer Not Allowed.
# Customer Capt Edward Gifford is black-listed.
# -----
# Anna None Miss
# Michael None Mr
# Johannes Joseph Mr
# Lalio None Mr
# August Sigfrid Mr
# Thomas Leonard Mr
# -----
# Customer Not Allowed.
# Customer Mr John None is black-listed.
# -----
# None None None
# Arthur Jackson Dr
# Mary None Miss
# Daniel J Mr
# Daniel Danielsen Mr
# Rene Aime Mr
# -----
# Customer Not Allowed.
# Customer Mr Niels Peder is black-listed.
# -----
# Dibo None Mr
# Roger None Mr
# Thomas J Mr
# Milton Clyde Mr
# Andrew G Mr
# William None Mr
# -----
# Customer Not Allowed.
# Customer Mr Benjamin None is black-listed.
# -----
# Stella Anna Miss
# William Fisher Mr
# Ristiu None Mr
# Richard None Mr
# Mara None Mrs
# Yousseff None Mr
# -----
# Customer Not Allowed.
# Customer Mr Martin None is black-listed.
# -----
# Oskar Arvid Mr
# Karl Johan Mr
# Thomas Jr Mr
# August None Mr
# William None Mr
# James None Mr
# -----
# Customer Not Allowed.
# Customer Mr Richard James is black-listed.
# -----
# Ernest Portage Mr
# Richard None Mr
# Wendla Maria Miss
# Albert None Mr
# None None None
# Nikola None Mr
# -----
# Customer Not Allowed.
# Customer Jonkheer John George is black-listed.
# -----
# John None Mr
# Len None Mr
# Thomas Joseph Mr
# Amin None Mr
# Albert None Mr
# Sara Rebecca Miss
# -----
# Customer Not Allowed.
# Customer Mr Maurice None is black-listed.
# -----
# Chang None Mr
# Pierre None Mr
# Augusta None Miss
# Peter L Mr
# Anthony None Mr
# Douglas Bullen Mr
# -----
# Customer Not Allowed.
# Customer Mr Marin None is black-listed.
# -----
# John None Rev
# Johan None Mr
# Peter Denis Mr
# Raihed None Mr
# Claus Peter Mr
# John William Mr
# -----
# Customer Not Allowed.
# Customer Miss Asuncion None is black-listed.
# -----
# None None None
# Philemon None Mr
# Cerin None Mr
# Frans Olof Mr
# Victor None Mr
# Kristo None Mr
# -----
# Customer Not Allowed.
# Customer Mr Johann None is black-listed.
# -----
# Gerda Ulrika Miss
# Frederick James Mr
# Henry Jr Mr
# Juozas None Rev
# Karl Howell Mr
# Patrick None Mr
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 527    None
# 528    None
# 529    None
# 530    None
# 531    None
# Length: 532, dtype: object

# %%
'''
customer_data = Customer(data.iloc[1]['last_name'], data.iloc[1]['first_name'], data.iloc[1]['title']);
print(customer_data.firstName, customer_data.lastName, customer_data.title)
'''
# Out:
# "\ncustomer_data = Customer(data.iloc[1]['last_name'], data.iloc[1]['first_name'], data.iloc[1]['title']);\nprint(customer_data.firstName, customer_data.lastName, customer_data.title)\n"
