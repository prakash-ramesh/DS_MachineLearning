# %% [markdown]
# 1. Read the three CSV files which contain the score of the same students in term1
# of each Subject
# 2. Remove the name and ethnicity column (to ensure confidentiality)
# 3. Fill missing score data with zero
# 4. Merge the three files
# 5. Change Sex(M/F) Column to 1/2 for further analysis
# 6. Store the data in a new file – ScoreFinal.csv

# %%
import pandas as pd
p_score = pd.read_csv('PhysicsScoreTerm1.csv')
m_score = pd.read_csv('MathScoreTerm1.csv')
d_score = pd.read_csv('DSScoreTerm1.csv')

# %%
print(p_score.describe(), '\n', m_score.describe(), '\n', d_score.describe())
# Out:
#             Score         Age          ID
# count  593.000000  599.000000  599.000000
# mean    70.598651   19.121870  300.000000
# std     15.997280    1.052234  173.060683
# min     27.000000   18.000000    1.000000
# 25%     61.000000   18.000000  150.500000
# 50%     78.000000   19.000000  300.000000
# 75%     84.000000   20.000000  449.500000
# max     94.000000   21.000000  599.000000
#              Score         Age          ID
# count  596.000000  599.000000  599.000000
# mean    74.348993   19.121870  300.000000
# std     16.217918    1.052234  173.060683
# min     31.000000   18.000000    1.000000
# 25%     65.000000   18.000000  150.500000
# 50%     78.500000   19.000000  300.000000
# 75%     88.000000   20.000000  449.500000
# max     95.000000   21.000000  599.000000
#              Score         Age          ID
# count  591.000000  599.000000  599.000000
# mean    68.367174   19.121870  300.000000
# std     16.161543    1.052234  173.060683
# ...

# %%
m_score.isnull().sum()
# Out:
# Name          0
# Score         3
# Age           0
# Ethinicity    0
# Subject       0
# Sex           0
# ID            0
# dtype: int64

# %%
p_score['Score'] = p_score['Score'].fillna(0)
m_score['Score'] = p_score['Score'].fillna(0)
d_score['Score'] = p_score['Score'].fillna(0)

# %%
m_score.head()
# Out:
#              Name  Score  Age         Ethinicity Subject Sex  ID
# 0  AI-KYUNG CHUNG   84.0   18     White American   Maths   M   1
# 1     ALAN HARVEY   81.0   19  European American   Maths   M   2
# 2    ALAN REYNAUD   41.0   19  European American   Maths   M   3
# 3  ALBERT CENDANA   78.0   18     White American   Maths   M   4
# 4  ALBERT HOLT JR   78.0   18     White American   Maths   F   5

# %%
df_mp = m_score.merge(p_score, how='left', on=['Name', 'Age', 'Ethinicity', 'Sex', 'ID'], suffixes=('_maths', '_physics'))

# %%
df_mpd = df_mp.merge(d_score, how='left', on=['Name', 'Age', 'Ethinicity', 'Sex', 'ID'])

# %%
df_mpd
# Out:
#                           Name  Score_maths  Age         Ethinicity  \
# 0               AI-KYUNG CHUNG         84.0   18     White American
# 1                  ALAN HARVEY         81.0   19  European American
# 2                 ALAN REYNAUD         41.0   19  European American
# 3               ALBERT CENDANA         78.0   18     White American
# 4               ALBERT HOLT JR         78.0   18     White American
# ..                         ...          ...  ...                ...
# 594                    WING NG         41.0   19     White American
# 595                YIFANG QIAN         71.0   18     White American
# 596           ZACHARY PUMPHREY         49.0   20     White American
# 597  ZEBA IMAN NAZEERI-SIMMONS         71.0   20           Hispanic
# 598            ZHI JIAR ZHUANG         69.0   19           Hispanic
#
#     Subject_maths Sex   ID  Score_physics Subject_physics  Score  \
# 0           Maths   M    1           84.0         Physics   84.0
# ...

# %%
df_mpd.drop(['Name', 'Ethinicity', 'Subject_maths', 'Subject_physics', 'Subject'], axis=1, inplace=True)

# %%
df_mpd.rename(columns={'Score': 'Score_datastructure'}, inplace=True)

# %%
df_mpd.isnull().sum()
# Out:
# Score_maths            0
# Age                    0
# Sex                    0
# ID                     0
# Score_physics          0
# Score_datastructure    0
# dtype: int64

# %%
df_mpd['Sex'].replace({'M': 1, 'F': 2}, inplace=True)

# %%
df_mpd
# Out:
#      Score_maths  Age  Sex   ID  Score_physics  Score_datastructure
# 0           84.0   18    1    1           84.0                 84.0
# 1           81.0   19    1    2           81.0                 81.0
# 2           41.0   19    1    3           41.0                 41.0
# 3           78.0   18    1    4           78.0                 78.0
# 4           78.0   18    2    5           78.0                 78.0
# ..           ...  ...  ...  ...            ...                  ...
# 594         41.0   19    2  595           41.0                 41.0
# 595         71.0   18    1  596           71.0                 71.0
# 596         49.0   20    1  597           49.0                 49.0
# 597         71.0   20    1  598           71.0                 71.0
# 598         69.0   19    1  599           69.0                 69.0
#
# [599 rows x 6 columns]

# %%
df_mpd.to_csv('ScoreFinal.csv')
